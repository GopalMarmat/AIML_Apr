# %%
print("Hello All")
# Out:
# Hello All

# %% [markdown]
# ## Indendation

# %%
if 2 == 2:
    print("both are equal")
else:
    print("testing")
# Out:
# both are equal

# %% [markdown]
# ## Comments

# %%
#this is Single comments
print("Single Line Comments")
"""This is 
multiline Comments"""
print("Multi Line Comments")
# Out:
# Single Line Comments
# Multi Line Comments

# %%
# Example code : Calculator

def calculator(a, b, condition):
    if condition == "add": #this conditon for addition
        return a+b
    elif condition=="sub": #this conditon for substraction
        return a-b
    elif condition == "mul": #this conditon for mutliplication
        return a*b
    elif condition == "div": #this conditon for division
        return a/b
    else:
        print("Please pass proper condition")
result=calculator(25,8,"add")
print(result)
# Out:
# 33

# %% [markdown]
# ## Variable and DataType
#
# ### Data Type
# 1. Integer
# 2. float
# 3. string
# 4. boolean

# %%
#Integer
a=25 #Integer variable

def calculator(a, b, condition):
    print("a variable types",type(a))
    if condition == "add": #this conditon for addition
        return a+b
    elif condition=="sub": #this conditon for substraction
        return a-b
    elif condition == "mul": #this conditon for mutliplication
        return a*b
    elif condition == "div": #this conditon for division
        return a/b
    else:
        print("Please pass proper condition")
result=calculator(25,8,"add")
print(result)
# Out:
# a variable types <class 'int'>
# 33

# %%
#float variable
a=25.12 #Float variable

def calculator(a, b, condition):
    print("a variable types",type(a))
    print("b variable types",type(b))
    if condition == "add": #this conditon for addition
        return a+b
    elif condition=="sub": #this conditon for substraction
        return a-b
    elif condition == "mul": #this conditon for mutliplication
        return a*b
    elif condition == "div": #this conditon for division
        return a/b
    else:
        print("Please pass proper condition")
result=calculator(25.8,12,"add")
print(result)
# Out:
# a variable types <class 'float'>
# b variable types <class 'int'>
# 37.8

# %%
#String
a="25" #String variable
name="Gopal" 

def calculator(a, b, condition):
    print("a variable types",type(a))
    print("b variable types",type(b))
    print("condition variable types",type(condition))
    if condition == "add": #this conditon for addition
        return a+b
    elif condition=="sub": #this conditon for substraction
        return a-b
    elif condition == "mul": #this conditon for mutliplication
        return a*b
    elif condition == "div": #this conditon for division
        return a/b
    else:
        print("Please pass proper condition")
result=calculator(25.8,12,"add")
print(result)
# Out:
# a variable types <class 'float'>
# b variable types <class 'int'>
# condition variable types <class 'str'>
# 37.8

# %%
# Boolean variable

a=False
print(type(a))
if a:
    print("Condition wad true")
else:
    print("Condition wad false")
# Out:
# <class 'bool'>
# Condition wad false

# %%
# Short summary DataType
a=25
print(type(a))
a=25.46
print(type(a))
a="AIML"
print(type(a))
a=False
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Type casting/Conversion

# %%
# Type Conversion From Integer to string and float
a=25
print(type(a),a)
a=str(a)
print(type(a),a)
a=float(a)
print(type(a),a)
# Out:
# <class 'int'> 25
# <class 'str'> 25
# <class 'float'> 25.0

# %%
a="25"
print(type(a),a)
a=int(a)
print(type(a),a)
# Out:
# <class 'str'> 25
# <class 'int'> 25

# %%
#Integer
a=25 #Integer variable

def calculator(a, b, condition):
    print("a variable types",type(a))
    if condition == "add": #this conditon for addition
        return a+b
    elif condition=="sub": #this conditon for substraction
        return a-b
    elif condition == "mul": #this conditon for mutliplication
        return a*b
    elif condition == "div": #this conditon for division
        return a/b
    else:
        print("Please pass proper condition")
result=calculator(25,"8","add")
print(result)
# Out:
# a variable types <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 16
#      12     elif condition == "div": #this conditon for division
#      13         return a/b
#      14     else:
#      15         print("Please pass proper condition")
# ---> 16 result=calculator(25,"8","add")
#      17 print(result)
#      18
#
# Cell In[30], line 7, in calculator(a, b, condition)
#       4 def calculator(a, b, condition):
#       5     print("a variable types",type(a))
#       6     if condition == "add": #this conditon for addition
# ----> 7         return a+b
#       8     elif condition=="sub": #this conditon for substraction
#       9         return a-b
#      10     elif condition == "mul": #this conditon for mutliplication
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
def calculator(a, b, condition):
    print("a variable types",type(a))
    b=int(b)
    if condition == "add": #this conditon for addition
        return a+b
    elif condition=="sub": #this conditon for substraction
        return a-b
    elif condition == "mul": #this conditon for mutliplication
        return a*b
    elif condition == "div": #this conditon for division
        return a/b
    else:
        print("Please pass proper condition")
result=calculator(25,"8","add")
print(result)
# Out:
# a variable types <class 'int'>
# 33

# %% [markdown]
# ## Practice
# 1. Create string Varible and Print your name
#
# 2. Create integer varible and perform Numerical Operation(Addition, Sub etc)
#
# 3. Perform Type Conversion From String to integer and Integer to string, Integer to float, Float to string
